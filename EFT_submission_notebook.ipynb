# %% [markdown]
# ## 1) Instalación (ejecutar en Colab o local)
# Ejecuta la siguiente celda para instalar dependencias en Colab. En local, utiliza `pip install -r requirements.txt`.

# %%
# En Colab: descomenta e instala las dependencias
# !pip install -r requirements.txt
print('Instalación: revisar README.md para instrucciones locales')

# %% [markdown]
# ## 2) Resumen del proyecto y cómo verificar indicadores de la rúbrica
#
# - `main_rag_agent_ev3.py`: aplicación Streamlit con agente RAG, métricas, logs estructurados y controles de seguridad (`sanitize_input`, `ethical_check`).
# - `EFT_compliance_checklist.md`: checklist con el mapeo de la rúbrica a evidencias en el repositorio.
# - Para la defensa: preparar diapositivas y notas por integrante (no incluidas aquí).

# %% [markdown]
# ## 3) Comprobaciones rápidas (no ejecutables en Colab)
#
# - Verifica que el archivo `.env` contiene `OPENAI_API_KEY` o `GITHUB_TOKEN` antes de ejecutar el servicio.
# - Para ejecutar la aplicación localmente: `streamlit run main_rag_agent_ev3.py`

# %% [markdown]
# ## 4) Análisis de logs (ejemplo)
# A continuación hay un ejemplo de cómo cargar un `logs_interactions.csv` exportado desde la aplicación y calcular métricas agregadas.

# %%
import pandas as pd
import os

# Si dispones de un CSV de logs generado por la app, cárgalo así:
# df = pd.read_csv('logs_interacciones_hbl_YYYYMMDD_HHMM.csv')
# print(df.head())
print('Celdas para análisis de logs: cargue su CSV exportado desde la aplicación.')

# %% [markdown]
# ## 5) Notas de entrega
# - Exporte este notebook a PDF (File -> Print / Save as PDF) para subir a la plataforma de entrega.
# - Incluya en el ZIP final: el PDF del informe, el notebook Colab, el código fuente (`main_rag_agent_ev3.py`) y la plantilla `.env.template`.
